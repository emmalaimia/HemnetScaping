# %%
import pandas as pd
import requests
import bs4 as bs
import pandas as pd
import re as re

# %%
#-*- coding: utf-8 -*-
import sys
print sys.stdin.encoding
# Out:
# None

# %%
print(räksmörgås)
# Out:
#   File "<ipython-input-3-1eab92a927d2>", line 1
#     print(räksmörgås)
#            ^
# SyntaxError: invalid syntax

# %%
url = 'https://www.hemnet.se/salda/bostader?location_ids%5B%5D=473379&sold_age=6m'

# %%
response = requests.get(url)

# %%
code = response.text

# %%
response.encoding
# Out:
# 'utf-8'

# %%
response.apparent_encoding
# Out:
# 'utf-8'

# %%
parsed = bs.BeautifulSoup(code, "html.parser", from_encoding='utf-8')

# %%
parsed.encode()
# Out:
# '\n<!DOCTYPE html>\n\n<!--[if IE 8 ]>    <html lang="sv-SE" dir="ltr" class="ie8"> <![endif]-->\n<!--[if IE 9 ]>    <html lang="sv-SE" dir="ltr" class="ie9"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!--> <html dir="ltr" lang="sv-SE"> <!--<![endif]-->\n<!--\n             hhhhhhhh\n        hhhhhhhhhhhhhhhhhh\n      hhhhh             hhhh\n    hhhhh                 hhhh\n   hhhh         hhh        hhhh\n   hhh       hhhhhhhhh      hhhh\n  hhhh     hhhhhhhhhhhh     hhhh\n  hhhh     hhhh    hhhh     hhhh\n  hhhh     hhhh    hhhh     hhhh\n   hhhh                    hhhh\n    hhhhh                 hhhh\n     hhhhhh            hhhhh\n   hhhhh hhhhhhhhhhhhhhhh\n  hhhh     hhhhhhhhhhh\n\n  Kul att du hittat hit! Vill du ocks\xc3\xa5 jobba p\xc3\xa5 en av Sveriges st\xc3\xb6rsta sajter med miljontals unika bes\xc3\xb6kare?\n  G\xc3\xb6r en spontanans\xc3\xb6kan p\xc3\xa5 https://jobba.hemnet.se/\n  -->\n<head>\n<meta charset="utf-8">\n<link href="//assets.hemnet.se" rel="dns-prefetch">\n<link href="//bilder.hemnet.se" rel="dns-prefetch">\n<link href="//maps.googleapis.com" rel="dns-prefetch">\n<link href="//eas4.emediate.eu" rel="dns-prefetch">\n<link href="//ads.pubmatic.com" rel="dns-prefetch">\n<title>  Slutpriser p\xc3\xa5 bost\xc3\xa4der - Kungsholmen, Stockholm\n</title>\n<meta content="3e8987af7589b374cab369f2d32e95b8" name="detectify-verification"/>\n<meta content="telephone=no" name="format-detection">\n<meta content="always" name="referrer"/>\n<meta content="MgOW5i2sIhcrdILu7eVDwzPcciV8KK3o3BEI2UNnqGQ" name="google-site-verification"/>\n<meta content="Bost\xc3\xa4der i Kungsholmen. P\xc3\xa5 Hemnet hittar du alla bost\xc3\xa4der som l\xc3\xa4genheter, villor, radhus, tomter och fritidshus till salu genom svenska fastighetsm\xc3\xa4klare" name="description">\n<meta content="initial-scale=1.0,width=device-width" name="viewport">\n<meta content="authenticity_token" name="csrf-param"/>\n<meta content="NgIg1fnQpr95wfcc79pXxQBT0PcN+iIog4RtaAGSWYWzrI0BrfFqoD72FcCL6oNj8dSvPLWoDOZT1f5dhdbLZA==" name="csrf-token"/>\n<link href="/favicon.ico" rel="shortcut icon" type="image/png"/>\n<link href="https://assets.hemnet.se/assets/images/touch_icons/iphone-retina.png" rel="apple-touch-icon-precomposed" sizes="114x114"/>\n<link href="https://assets.hemnet.se/assets/images/touch_icons/ipad-retina.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>\n<link href="https://assets.hemnet.se/assets/packs/legacy-site.93616e36aad72e833059.css" media="screen, print" rel="stylesheet"/>\n<link href="https://assets.hemnet.se/assets/packs/hemnet.ffac90d655351856c98e.css" media="screen, print" rel="stylesheet"/>\n<link href="https://assets.hemnet.se/assets/packs/layout.00e99e6a2ae996750010.css" media="screen, print" rel="stylesheet"/>\n<link href="https://assets.hemnet.se/assets/packs/print.3b5699771584b06f9875.css" media="print" rel="stylesheet"/>\n<script>document.createElement("picture"); /* Picture element HTML5 shiv for Picturefill */</script>\n<script async="async" src="https://assets.hemnet.se/assets/javascripts/vendor/picturefill-3.0.2.min.js"></script>\n<script src="https://assets.hemnet.se/assets/javascripts/h3-head.min.js?1495095337"></script>\n<script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>\n<script>\n    googletag.cmd.push(function() {\n      var slot = googletag.defineSlot(\'/20339512601/top\', [[980, 240], [980, 120], [320, 160], [1440, 700]], "ad-unit-0");\n        slot.setTargeting("item_types", [1]);\n        slot.setTargeting("municipality", [199]);\n        slot.setTargeting("district", [5]);\n        slot.setTargeting("region", [12]);\n        slot.setTargeting("country", [1]);\n      slot.setTargeting("page", "search_sold");\n      slot.addService(googletag.pubads());\n      var mapping = googletag.sizeMapping()\n        .addSize([640, 0], [[980, 240], [980, 120], [1440, 700]])\n        .addSize([0, 0], [320, 160])\n        .build();\n      slot.defineSizeMapping(mapping);\n    });\n  </script>\n ...

# %%
listings = parsed.findAll('div',{'class':'sold-property-listing'})

# %%
print listings
# Out:
# [<div class="sold-property-listing">\n<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Gyllenborgsgatan 18</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Thorildsplan,\n</span>      Stockholm\n    </div>\n</div>\n<div class="sold-property-listing__size">\n<div class="clear-children">\n<div class="sold-property-listing__subheading sold-property-listing--left">\n            34,5\xa0m\xb2\n          \xa0\n            1\xa0rum\n        </div>\n<div class="sold-property-listing__fee">\n            1\xa0850\xa0kr/m\xe5n\n          </div>\n</div>\n</div>\n<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0100\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          89\xa0855 kr/m\xb2\n        </div>\n</div>\n</div>\n<div class="sold-property-listing__price-change">\n<i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +15%\n    </div>\n<a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-thorildsplan-stockholms-kommun-gyllenborgsgatan-18-677968">\n    \xa0\n</a>\n<div class="sold-property-listing__broker">\n<a href="/maklare/salda/304951" onclick=";hnt.tl('/tally/maklarfirma/304951/sold_listing_sold_clicks');">Erik Olsson Fastighetsf\xf6rmedling</a>\n</div>\n</div>, <div class="sold-property-listing">\n<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Industrigatan 14</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>\n<div class="sold-property-listing__size">\n<div class="clear-children">\n<div class="sold-property-listing__subheading sold-property-listing--left">\n            34\xa0m\xb2\n          \xa0\n            1\xa0rum\n        </div>\n<div class="sold-property-listing__fee">\n            2\xa0281\xa0kr/m\xe5n\n          </div>\n</div>\n</div>\n<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0130\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          92\xa0059 kr/m\xb2\n        </div>\n</div>\n</div>\n<div class="sold-property-listing__price-change">\n<i class="fa fa-arrow-circle-o-up fa- ...

# %%
for entry in listings:
    print entry[:5]
    print ' '
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-8423d4e731d2> in <module>()
#       1 for entry in listings:
# ----> 2     print entry[:5]
#       3     print ' '
#
# /Users/emma/anaconda/lib/python2.7/site-packages/bs4/element.pyc in __getitem__(self, key)
#     995         """tag[key] returns the value of the 'key' attribute for the tag,
#     996         and throws an exception if it's not there."""
# --> 997         return self.attrs[key]
#     998
#     999     def __iter__(self):
#
# TypeError: unhashable type

# %%
type(listings)
# Out:
# bs4.element.ResultSet

# %%
for entry in listings:
    print entry
    print ' '
# Out:
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Gyllenborgsgatan 18</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Thorildsplan,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             34,5 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 850 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 100 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           89 855 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +15%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-thorildsplan-stockholms-kommun-gyllenborgsgatan-18-677968">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/304951" onclick=";hnt.tl('/tally/maklarfirma/304951/sold_listing_sold_clicks');">Erik Olsson Fastighetsförmedling</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Industrigatan 14</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             34 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 281 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 130 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           92 059 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +8%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-stockholms-kommun-industrigatan-14-677734">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/36331" onclick=";hnt.tl('/tally/maklarfirma/36331/sold_listing_sold_clicks');">ERA Bostad Sthlm</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Industrigatan 5, 4tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             37 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 339 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 750 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           101 351 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +17%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stockholms-kommun-industrigatan-5,-4tr-678607">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/22747" onclick=";hnt.tl('/tally/maklarfirma/22747/sold_listing_sold_clicks');">Mäklarhuset Stockholm Innerstan</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Alströmergatan 21, 2 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             95,5 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 870 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 7 700 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           80 628 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-down fa-lg price-icon--down"></i> -1%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-4rum-kungsholmen-stockholms-kommun-alstromergatan-21,-2-tr-677998">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Wivalliusgatan 17, 2 tr (5 tr)</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen - Marieberg,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             42 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 444 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 800 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           90 476 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +10%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-marieberg-stockholms-kommun-wivalliusgatan-17,-2-tr-5-tr-677931">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Sankt Göransgatan 72, 4/4tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen - Fridhemsplan,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             26 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             564 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 330 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           128 077 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-fridhemsplan-stockholms-kommun-sankt-goransgatan-72,-4-4tr-677763">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/29787" onclick=";hnt.tl('/tally/maklarfirma/29787/sold_listing_sold_clicks');">BOSTHLM Fastighetsmäklare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Ernst Ahlgrens väg 5, 2tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen Fredhäll,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             44 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 373 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 450 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           78 409 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +15%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-fredhall-stockholms-kommun-ernst-ahlgrens-vag-5,-2tr-677936">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/709471" onclick=";hnt.tl('/tally/maklarfirma/709471/sold_listing_sold_clicks');">MOHV Kungsholmen AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Patentgatan 9</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Lilla Essingen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             62 m²
#
#             2,5 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 021 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 4 680 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           75 484 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +5%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2,5rum-lilla-essingen-stockholms-kommun-patentgatan-9-678003">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kronobergsgatan 18, 3 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             90 m²
#
#             3,5 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 969 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 7 350 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           81 667 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-down fa-lg price-icon--down"></i> -4%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-3,5rum-kungsholmen-stockholms-kommun-kronobergsgatan-18,-3-tr-678409">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Vitalisvägen 11</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen/Fredhäll,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             38 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 115 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 2 975 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           78 289 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +21%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-fredhall-stockholms-kommun-vitalisvagen-11-678241">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kungsholmstorg 11, 5 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             106 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 872 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 11 850 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           111 792 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +22%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-4rum-kungsholmen-stockholms-kommun-kungsholmstorg-11,-5-tr-677272">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kungsklippan 22</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             37,5 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 749 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 600 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           96 000 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +22%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stockholms-kommun-kungsklippan-22-677290">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/427251" onclick=";hnt.tl('/tally/maklarfirma/427251/sold_listing_sold_clicks');">Erik Olsson Fastighetsförmedling</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Hjärnegatan 9, 1,5 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             76 m²
#
#             3 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 452 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 6 675 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           87 829 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +6%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-3rum-kungsholmen-stockholms-kommun-hjarnegatan-9,-1,5-tr-677283">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Svarvargatan 10, 2 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen Fridhemsplan,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             24 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 285 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 2 600 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           108 333 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +37%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-fridhemsplan-stockholms-kommun-svarvargatan-10,-2-tr-677313">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/424" onclick=";hnt.tl('/tally/maklarfirma/424/sold_listing_sold_clicks');">HusmanHagberg Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Creutzgatan 5, Vån 4/4</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             37 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 994 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 250 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           87 838 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +16%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-stockholms-kommun-creutzgatan-5,-van-4-4-677415">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/29607" onclick=";hnt.tl('/tally/maklarfirma/29607/sold_listing_sold_clicks');">Länsförsäkringar Fastighetsförmedling Stockholm - Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Vitalisvägen 3, vån 3</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Fredhäll,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             42 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 203 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 400 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           80 952 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +15%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-fredhall-stockholms-kommun-vitalisvagen-3,-van-3-677758">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/9045" onclick=";hnt.tl('/tally/maklarfirma/9045/sold_listing_sold_clicks');">Notar</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Ulriksborgsgatan 9, 8 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             40 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 582 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 500 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           87 500 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +18%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-stockholms-kommun-ulriksborgsgatan-9,-8-tr-677778">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/1927" onclick=";hnt.tl('/tally/maklarfirma/1927/sold_listing_sold_clicks');">Bostadsrättsspecialisten</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Pär Lagerkvists gata 30, 7 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen Hornsbergs Strand,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             74 m²
#
#             3 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 428 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 6 150 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           83 108 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +4%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-3rum-kungsholmen-hornsbergs-strand-stockholms-kommun-par-lagerkvists-gata-30,-7-tr-677288">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/424" onclick=";hnt.tl('/tally/maklarfirma/424/sold_listing_sold_clicks');">HusmanHagberg Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Frödingsvägen 6, 1 1/2 TR</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen - Fredhäll,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             38 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 787 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 350 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           88 158 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-fredhall-stockholms-kommun-frodingsvagen-6,-1-1-2-tr-677104">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/29787" onclick=";hnt.tl('/tally/maklarfirma/29787/sold_listing_sold_clicks');">BOSTHLM Fastighetsmäklare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="13" viewbox="0 0 13 13" width="13" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Radhus</span></desc><title>icon_radhus_inactive</title><path d="M6.5 3.25L4.062 0 0 5.417v6.5C0 12.515.485 13 1.083 13H3.25V9.208h1.625V13h3.25V9.208H9.75V13h2.167c.598 0 1.083-.485 1.083-1.083v-6.5L8.937 0 6.5 3.25z" fill="#45A366" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Grubbensringen 6, 3tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrätt
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             99 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             6 483 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 7 700 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/radhus-4rum-kungsholmen-stockholms-kommun-grubbensringen-6,-3tr-677641">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/29607" onclick=";hnt.tl('/tally/maklarfirma/29607/sold_listing_sold_clicks');">Länsförsäkringar Fastighetsförmedling Stockholm - Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Industrigatan 16</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             49 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 494 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 4 150 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           84 694 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +4%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stockholms-kommun-industrigatan-16-677130">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/701671" onclick=";hnt.tl('/tally/maklarfirma/701671/sold_listing_sold_clicks');">Svensk Fastighetsförmedling Sthlm Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Fridhemsgatan 62, 3 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             47 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 898 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 5 260 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           111 915 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +35%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stockholms-kommun-fridhemsgatan-62,-3-tr-677150">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/701671" onclick=";hnt.tl('/tally/maklarfirma/701671/sold_listing_sold_clicks');">Svensk Fastighetsförmedling Sthlm Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Sankt Göransgatan 135, 2tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             113,5 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             6 529 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 8 400 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           74 009 kr/m²
#         </div>
# </div>
# </div>
# ...
# <span class="item-link">
#           Kungsholmen/Stadshagen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             53,5 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 473 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 4 550 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 15 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           85 047 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +14%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stadshagen-stockholms-kommun-kellgrensgatan-10,-10-tr-675530">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kungsholms Strand 107</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             113 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             6 399 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 9 900 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 15 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           87 611 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-4rum-kungsholmen-stockholms-kommun-kungsholms-strand-107-675388">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/8985" onclick=";hnt.tl('/tally/maklarfirma/8985/sold_listing_sold_clicks');">Notar</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kaplansbacken 5, 7 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             35 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 861 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 850 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 14 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           110 000 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +29%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-stockholms-kommun-kaplansbacken-5,-7-tr-675051">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Chapmansgatan 5</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             87 m²
#
#             2,5 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 776 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 8 700 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 13 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           100 000 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2,5rum-kungsholmen-stockholms-kommun-chapmansgatan-5-674666">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/2051" onclick=";hnt.tl('/tally/maklarfirma/2051/sold_listing_sold_clicks');">Living Fastighetsmäkleri</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Ola Hanssonsgatan 5</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kristineberg,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             37 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 437 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 425 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 13 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           92 568 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +37%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kristineberg-stockholms-kommun-ola-hanssonsgatan-5-674613">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/427251" onclick=";hnt.tl('/tally/maklarfirma/427251/sold_listing_sold_clicks');">Erik Olsson Fastighetsförmedling</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Pipersgatan 26</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             120 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             4 935 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 10 600 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 13 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           88 333 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +12%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-4rum-kungsholmen-stockholms-kommun-pipersgatan-26-674606">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/303735" onclick=";hnt.tl('/tally/maklarfirma/303735/sold_listing_sold_clicks');">Erik Olsson Fastighetsförmedling</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kungsklippan 20</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen/Kungsholmstorg,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             38,5 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 807 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 4 000 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 12 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           103 896 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +18%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-kungsholmstorg-stockholms-kommun-kungsklippan-20-674795">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Chapmansgatan 2</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             83 m²
#
#             3,5 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 878 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 6 880 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 12 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           82 892 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +4%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-3,5rum-kungsholmen-stockholms-kommun-chapmansgatan-2-674415">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/2183" onclick=";hnt.tl('/tally/maklarfirma/2183/sold_listing_sold_clicks');">Bjurfors Vasastan Kungsholmen</a>
# </div>
# </div>

# %%
listings[0]
# Out:
# <div class="sold-property-listing">\n<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Gyllenborgsgatan 18</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Thorildsplan,\n</span>      Stockholm\n    </div>\n</div>\n<div class="sold-property-listing__size">\n<div class="clear-children">\n<div class="sold-property-listing__subheading sold-property-listing--left">\n            34,5\xa0m\xb2\n          \xa0\n            1\xa0rum\n        </div>\n<div class="sold-property-listing__fee">\n            1\xa0850\xa0kr/m\xe5n\n          </div>\n</div>\n</div>\n<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0100\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          89\xa0855 kr/m\xb2\n        </div>\n</div>\n</div>\n<div class="sold-property-listing__price-change">\n<i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +15%\n    </div>\n<a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-thorildsplan-stockholms-kommun-gyllenborgsgatan-18-677968">\n    \xa0\n</a>\n<div class="sold-property-listing__broker">\n<a href="/maklare/salda/304951" onclick=";hnt.tl('/tally/maklarfirma/304951/sold_listing_sold_clicks');">Erik Olsson Fastighetsf\xf6rmedling</a>\n</div>\n</div>

# %%
#Slutpris

# %%
for entry in listings:
    print(entry.findAll('div',{'class':'sold-property-listing__price'}))
    print " "
# Out:
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0100\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          89\xa0855 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0130\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          92\xa0059 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0750\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          101\xa0351 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 7\xa0700\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          80\xa0628 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0800\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          90\xa0476 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0330\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          128\xa0077 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0450\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          78\xa0409 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 4\xa0680\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          75\xa0484 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 7\xa0350\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          81\xa0667 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 2\xa0975\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          78\xa0289 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 11\xa0850\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          111\xa0792 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0600\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          96\xa0000 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 6\xa0675\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          87\xa0829 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 2\xa0600\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          108\xa0333 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0250\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          87\xa0838 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0400\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          80\xa0952 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0500\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          87\xa0500 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 6\xa0150\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          83\xa0108 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0350\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          88\xa0158 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 7\xa0700\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 4\xa0150\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          84\xa0694 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 5\xa0260\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          111\xa0915 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 8\xa0400\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          74\xa0009 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 4\xa0825\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          74\xa0231 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0800\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          74\xa0510 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 8\xa0000\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          65\xa0306 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 7\xa0350\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          93\xa0038 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 10\xa0350\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          101\xa0471 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 8\xa0550\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          81\xa0429 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 5\xa0600\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          94\xa0915 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 7\xa0030\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          103\xa0382 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0800\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          102\xa0703 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 5\xa0500\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          96\xa0491 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 7\xa0810\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          100\xa0774 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 6\xa0100\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          82\xa0432 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 2\xa0650\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          101\xa0923 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 7\xa0200\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 16 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          97\xa0297 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 5\xa0900\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 16 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          103\xa0509 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0450\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 16 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          88\xa0462 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0220\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 16 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          94\xa0706 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0250\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 16 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          104\xa0839 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 5\xa0150\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 16 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          80\xa0469 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 4\xa0550\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 15 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          85\xa0047 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 9\xa0900\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 15 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          87\xa0611 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0850\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 14 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          110\xa0000 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 8\xa0700\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 13 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          100\xa0000 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0425\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 13 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          92\xa0568 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 10\xa0600\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 13 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          88\xa0333 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 4\xa0000\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 12 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          103\xa0896 kr/m\xb2\n        </div>\n</div>\n</div>]
#
# [<div class="sold-property-listing__price">\n<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 6\xa0880\xa0000 kr\n</span> </div>\n<div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 12 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          82\xa0892 kr/m\xb2\n        </div>\n</div>\n</div>]

# %%
for entry in listings:
    subentry = entry.findAll('div',{'class':'sold-property-listing__price'})
    for sub in subentry:
        sub2 = sub.findAll('div', {'class': 'clear-children'})
        print sub2
        print ' '
# Out:
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0100\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          89\xa0855 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0130\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          92\xa0059 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0750\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          101\xa0351 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 7\xa0700\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          80\xa0628 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0800\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          90\xa0476 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0330\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          128\xa0077 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0450\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          78\xa0409 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 4\xa0680\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 19 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          75\xa0484 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 7\xa0350\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          81\xa0667 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 2\xa0975\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          78\xa0289 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 11\xa0850\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          111\xa0792 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0600\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          96\xa0000 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 6\xa0675\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          87\xa0829 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 2\xa0600\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          108\xa0333 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0250\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          87\xa0838 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0400\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          80\xa0952 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0500\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          87\xa0500 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 6\xa0150\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          83\xa0108 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0350\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          88\xa0158 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 7\xa0700\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 4\xa0150\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          84\xa0694 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 5\xa0260\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          111\xa0915 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 8\xa0400\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          74\xa0009 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 4\xa0825\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 18 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          74\xa0231 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0800\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          74\xa0510 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 8\xa0000\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          65\xa0306 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 7\xa0350\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          93\xa0038 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 10\xa0350\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          101\xa0471 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 8\xa0550\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          81\xa0429 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 5\xa0600\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          94\xa0915 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 7\xa0030\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          103\xa0382 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0800\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          102\xa0703 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 5\xa0500\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          96\xa0491 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 7\xa0810\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          100\xa0774 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 6\xa0100\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          82\xa0432 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 2\xa0650\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 17 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          101\xa0923 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 7\xa0200\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 16 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          97\xa0297 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 5\xa0900\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 16 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          103\xa0509 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0450\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 16 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          88\xa0462 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0220\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 16 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          94\xa0706 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0250\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 16 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          104\xa0839 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 5\xa0150\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 16 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          80\xa0469 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 4\xa0550\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 15 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          85\xa0047 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 9\xa0900\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 15 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          87\xa0611 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0850\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 14 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          110\xa0000 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 8\xa0700\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 13 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          100\xa0000 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0425\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 13 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          92\xa0568 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 10\xa0600\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 13 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          88\xa0333 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 4\xa0000\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 12 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          103\xa0896 kr/m\xb2\n        </div>\n</div>]
#
# [<div class="clear-children">\n<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 6\xa0880\xa0000 kr\n</span> </div>, <div class="clear-children">\n<div class="sold-property-listing__sold-date sold-property-listing--left">\n          S\xe5ld 12 maj 2017\n        </div>\n<div class="sold-property-listing__price-per-m2 sold-property-listing--left">\n          82\xa0892 kr/m\xb2\n        </div>\n</div>]

# %%
prices_html = []

for entry in listings:
    subentry = entry.findAll('div',{'class':'sold-property-listing__price'})
    for sub in subentry:
        sub2 = sub.findAll('div', {'class': 'clear-children'})
        for sub3 in sub2:
            price = sub3.findAll('span', {'class': 'sold-property-listing__subheading sold-property-listing--left'})
            if len(price)>0:
                prices_html.append(price)

# %%
len(prices_html)
# Out:
# 50

# %%
print prices_html[0]
# Out:
# [<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0100\xa0000 kr\n</span>]

# %%
prices_html[1]
# Out:
# [<span class="sold-property-listing__subheading sold-property-listing--left">\n        Slutpris 3\xa0130\xa0000 kr\n</span>]

# %%
prices_to_clean = []

for price in prices_html:
    location = str(price).find('Slut')
    price_short = str(price)[location:]
    prices_to_clean.append(price_short)

# %%
prices_to_clean
# Out:
# ['Slutpris 3\\xa0100\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0130\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0750\\xa0000 kr\\n</span>]',
#  'Slutpris 7\\xa0700\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0800\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0330\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0450\\xa0000 kr\\n</span>]',
#  'Slutpris 4\\xa0680\\xa0000 kr\\n</span>]',
#  'Slutpris 7\\xa0350\\xa0000 kr\\n</span>]',
#  'Slutpris 2\\xa0975\\xa0000 kr\\n</span>]',
#  'Slutpris 11\\xa0850\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0600\\xa0000 kr\\n</span>]',
#  'Slutpris 6\\xa0675\\xa0000 kr\\n</span>]',
#  'Slutpris 2\\xa0600\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0250\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0400\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0500\\xa0000 kr\\n</span>]',
#  'Slutpris 6\\xa0150\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0350\\xa0000 kr\\n</span>]',
#  'Slutpris 7\\xa0700\\xa0000 kr\\n</span>]',
#  'Slutpris 4\\xa0150\\xa0000 kr\\n</span>]',
#  'Slutpris 5\\xa0260\\xa0000 kr\\n</span>]',
#  'Slutpris 8\\xa0400\\xa0000 kr\\n</span>]',
#  'Slutpris 4\\xa0825\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0800\\xa0000 kr\\n</span>]',
#  'Slutpris 8\\xa0000\\xa0000 kr\\n</span>]',
#  'Slutpris 7\\xa0350\\xa0000 kr\\n</span>]',
#  'Slutpris 10\\xa0350\\xa0000 kr\\n</span>]',
#  'Slutpris 8\\xa0550\\xa0000 kr\\n</span>]',
#  'Slutpris 5\\xa0600\\xa0000 kr\\n</span>]',
#  'Slutpris 7\\xa0030\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0800\\xa0000 kr\\n</span>]',
#  'Slutpris 5\\xa0500\\xa0000 kr\\n</span>]',
#  'Slutpris 7\\xa0810\\xa0000 kr\\n</span>]',
#  'Slutpris 6\\xa0100\\xa0000 kr\\n</span>]',
#  'Slutpris 2\\xa0650\\xa0000 kr\\n</span>]',
#  'Slutpris 7\\xa0200\\xa0000 kr\\n</span>]',
#  'Slutpris 5\\xa0900\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0450\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0220\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0250\\xa0000 kr\\n</span>]',
#  'Slutpris 5\\xa0150\\xa0000 kr\\n</span>]',
#  'Slutpris 4\\xa0550\\xa0000 kr\\n</span>]',
#  'Slutpris 9\\xa0900\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0850\\xa0000 kr\\n</span>]',
#  'Slutpris 8\\xa0700\\xa0000 kr\\n</span>]',
#  'Slutpris 3\\xa0425\\xa0000 kr\\n</span>]',
#  'Slutpris 10\\xa0600\\xa0000 kr\\n</span>]',
#  'Slutpris 4\\xa0000\\xa0000 kr\\n</span>]',
#  'Slutpris 6\\xa0880\\xa0000 kr\\n</span>]']

# %%
clean_prices = []

test = prices_to_clean[0]

test
# Out:
# 'Slutpris 3\\xa0100\\xa0000 kr\\n</span>]'

# %%
test.find('\\xar')
# Out:
# -1

# %%
filter(str.isdigit, test)
# Out:
# '301000000'

# %%
remove_loc = test.find('\\xa')

while remove_loc>=0:
    test = test[:remove_loc] + test[remove_loc+4:]
    remove_loc = test.find('\\xa')

# %%
test
# Out:
# 'Slutpris 3100000 kr\\n</span>]'

# %%
clean_prices = []

for price in prices_to_clean:
    remove_loc = price.find('\\xa0')
    while remove_loc>=0:
        price = price[:remove_loc] + price[remove_loc+4:]
        remove_loc = price.find('\\xa0')
    price = filter(str.isdigit, price)
    clean_prices.append(price)

# %%
clean_prices
# Out:
# ['3100000',
#  '3130000',
#  '3750000',
#  '7700000',
#  '3800000',
#  '3330000',
#  '3450000',
#  '4680000',
#  '7350000',
#  '2975000',
#  '11850000',
#  '3600000',
#  '6675000',
#  '2600000',
#  '3250000',
#  '3400000',
#  '3500000',
#  '6150000',
#  '3350000',
#  '7700000',
#  '4150000',
#  '5260000',
#  '8400000',
#  '4825000',
#  '3800000',
#  '8000000',
#  '7350000',
#  '10350000',
#  '8550000',
#  '5600000',
#  '7030000',
#  '3800000',
#  '5500000',
#  '7810000',
#  '6100000',
#  '2650000',
#  '7200000',
#  '5900000',
#  '3450000',
#  '3220000',
#  '3250000',
#  '5150000',
#  '4550000',
#  '9900000',
#  '3850000',
#  '8700000',
#  '3425000',
#  '10600000',
#  '4000000',
#  '6880000']

# %%
for l in listings:
    print l
    print ' '
# Out:
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Gyllenborgsgatan 18</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Thorildsplan,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             34,5 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 850 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 100 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           89 855 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +15%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-thorildsplan-stockholms-kommun-gyllenborgsgatan-18-677968">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/304951" onclick=";hnt.tl('/tally/maklarfirma/304951/sold_listing_sold_clicks');">Erik Olsson Fastighetsförmedling</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Industrigatan 14</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             34 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 281 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 130 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           92 059 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +8%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-stockholms-kommun-industrigatan-14-677734">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/36331" onclick=";hnt.tl('/tally/maklarfirma/36331/sold_listing_sold_clicks');">ERA Bostad Sthlm</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Industrigatan 5, 4tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             37 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 339 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 750 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           101 351 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +17%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stockholms-kommun-industrigatan-5,-4tr-678607">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/22747" onclick=";hnt.tl('/tally/maklarfirma/22747/sold_listing_sold_clicks');">Mäklarhuset Stockholm Innerstan</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Alströmergatan 21, 2 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             95,5 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 870 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 7 700 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           80 628 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-down fa-lg price-icon--down"></i> -1%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-4rum-kungsholmen-stockholms-kommun-alstromergatan-21,-2-tr-677998">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Wivalliusgatan 17, 2 tr (5 tr)</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen - Marieberg,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             42 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 444 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 800 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           90 476 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +10%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-marieberg-stockholms-kommun-wivalliusgatan-17,-2-tr-5-tr-677931">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Sankt Göransgatan 72, 4/4tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen - Fridhemsplan,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             26 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             564 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 330 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           128 077 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-fridhemsplan-stockholms-kommun-sankt-goransgatan-72,-4-4tr-677763">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/29787" onclick=";hnt.tl('/tally/maklarfirma/29787/sold_listing_sold_clicks');">BOSTHLM Fastighetsmäklare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Ernst Ahlgrens väg 5, 2tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen Fredhäll,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             44 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 373 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 450 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           78 409 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +15%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-fredhall-stockholms-kommun-ernst-ahlgrens-vag-5,-2tr-677936">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/709471" onclick=";hnt.tl('/tally/maklarfirma/709471/sold_listing_sold_clicks');">MOHV Kungsholmen AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Patentgatan 9</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Lilla Essingen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             62 m²
#
#             2,5 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 021 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 4 680 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           75 484 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +5%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2,5rum-lilla-essingen-stockholms-kommun-patentgatan-9-678003">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kronobergsgatan 18, 3 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             90 m²
#
#             3,5 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 969 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 7 350 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           81 667 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-down fa-lg price-icon--down"></i> -4%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-3,5rum-kungsholmen-stockholms-kommun-kronobergsgatan-18,-3-tr-678409">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Vitalisvägen 11</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen/Fredhäll,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             38 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 115 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 2 975 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           78 289 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +21%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-fredhall-stockholms-kommun-vitalisvagen-11-678241">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kungsholmstorg 11, 5 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             106 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 872 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 11 850 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           111 792 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +22%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-4rum-kungsholmen-stockholms-kommun-kungsholmstorg-11,-5-tr-677272">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kungsklippan 22</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             37,5 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 749 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 600 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           96 000 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +22%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stockholms-kommun-kungsklippan-22-677290">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/427251" onclick=";hnt.tl('/tally/maklarfirma/427251/sold_listing_sold_clicks');">Erik Olsson Fastighetsförmedling</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Hjärnegatan 9, 1,5 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             76 m²
#
#             3 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 452 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 6 675 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           87 829 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +6%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-3rum-kungsholmen-stockholms-kommun-hjarnegatan-9,-1,5-tr-677283">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Svarvargatan 10, 2 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen Fridhemsplan,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             24 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 285 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 2 600 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           108 333 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +37%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-fridhemsplan-stockholms-kommun-svarvargatan-10,-2-tr-677313">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/424" onclick=";hnt.tl('/tally/maklarfirma/424/sold_listing_sold_clicks');">HusmanHagberg Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Creutzgatan 5, Vån 4/4</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             37 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 994 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 250 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           87 838 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +16%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-stockholms-kommun-creutzgatan-5,-van-4-4-677415">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/29607" onclick=";hnt.tl('/tally/maklarfirma/29607/sold_listing_sold_clicks');">Länsförsäkringar Fastighetsförmedling Stockholm - Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Vitalisvägen 3, vån 3</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Fredhäll,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             42 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 203 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 400 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           80 952 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +15%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-fredhall-stockholms-kommun-vitalisvagen-3,-van-3-677758">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/9045" onclick=";hnt.tl('/tally/maklarfirma/9045/sold_listing_sold_clicks');">Notar</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Ulriksborgsgatan 9, 8 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             40 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 582 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 500 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           87 500 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +18%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-stockholms-kommun-ulriksborgsgatan-9,-8-tr-677778">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/1927" onclick=";hnt.tl('/tally/maklarfirma/1927/sold_listing_sold_clicks');">Bostadsrättsspecialisten</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Pär Lagerkvists gata 30, 7 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen Hornsbergs Strand,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             74 m²
#
#             3 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 428 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 6 150 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           83 108 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +4%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-3rum-kungsholmen-hornsbergs-strand-stockholms-kommun-par-lagerkvists-gata-30,-7-tr-677288">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/424" onclick=";hnt.tl('/tally/maklarfirma/424/sold_listing_sold_clicks');">HusmanHagberg Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Frödingsvägen 6, 1 1/2 TR</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen - Fredhäll,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             38 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 787 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 350 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           88 158 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-fredhall-stockholms-kommun-frodingsvagen-6,-1-1-2-tr-677104">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/29787" onclick=";hnt.tl('/tally/maklarfirma/29787/sold_listing_sold_clicks');">BOSTHLM Fastighetsmäklare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="13" viewbox="0 0 13 13" width="13" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Radhus</span></desc><title>icon_radhus_inactive</title><path d="M6.5 3.25L4.062 0 0 5.417v6.5C0 12.515.485 13 1.083 13H3.25V9.208h1.625V13h3.25V9.208H9.75V13h2.167c.598 0 1.083-.485 1.083-1.083v-6.5L8.937 0 6.5 3.25z" fill="#45A366" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Grubbensringen 6, 3tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrätt
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             99 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             6 483 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 7 700 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/radhus-4rum-kungsholmen-stockholms-kommun-grubbensringen-6,-3tr-677641">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/29607" onclick=";hnt.tl('/tally/maklarfirma/29607/sold_listing_sold_clicks');">Länsförsäkringar Fastighetsförmedling Stockholm - Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Industrigatan 16</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             49 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 494 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 4 150 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           84 694 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +4%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stockholms-kommun-industrigatan-16-677130">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/701671" onclick=";hnt.tl('/tally/maklarfirma/701671/sold_listing_sold_clicks');">Svensk Fastighetsförmedling Sthlm Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Fridhemsgatan 62, 3 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             47 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 898 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 5 260 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           111 915 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +35%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stockholms-kommun-fridhemsgatan-62,-3-tr-677150">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/701671" onclick=";hnt.tl('/tally/maklarfirma/701671/sold_listing_sold_clicks');">Svensk Fastighetsförmedling Sthlm Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Sankt Göransgatan 135, 2tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             113,5 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             6 529 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 8 400 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           74 009 kr/m²
#         </div>
# </div>
# </div>
# ...
# <span class="item-link">
#           Kungsholmen/Stadshagen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             53,5 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 473 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 4 550 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 15 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           85 047 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +14%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stadshagen-stockholms-kommun-kellgrensgatan-10,-10-tr-675530">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kungsholms Strand 107</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             113 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             6 399 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 9 900 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 15 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           87 611 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-4rum-kungsholmen-stockholms-kommun-kungsholms-strand-107-675388">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/8985" onclick=";hnt.tl('/tally/maklarfirma/8985/sold_listing_sold_clicks');">Notar</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kaplansbacken 5, 7 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             35 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 861 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 850 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 14 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           110 000 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +29%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-stockholms-kommun-kaplansbacken-5,-7-tr-675051">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Chapmansgatan 5</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             87 m²
#
#             2,5 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 776 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 8 700 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 13 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           100 000 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2,5rum-kungsholmen-stockholms-kommun-chapmansgatan-5-674666">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/2051" onclick=";hnt.tl('/tally/maklarfirma/2051/sold_listing_sold_clicks');">Living Fastighetsmäkleri</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Ola Hanssonsgatan 5</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kristineberg,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             37 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 437 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 425 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 13 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           92 568 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +37%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kristineberg-stockholms-kommun-ola-hanssonsgatan-5-674613">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/427251" onclick=";hnt.tl('/tally/maklarfirma/427251/sold_listing_sold_clicks');">Erik Olsson Fastighetsförmedling</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Pipersgatan 26</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             120 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             4 935 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 10 600 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 13 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           88 333 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +12%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-4rum-kungsholmen-stockholms-kommun-pipersgatan-26-674606">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/303735" onclick=";hnt.tl('/tally/maklarfirma/303735/sold_listing_sold_clicks');">Erik Olsson Fastighetsförmedling</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kungsklippan 20</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen/Kungsholmstorg,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             38,5 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 807 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 4 000 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 12 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           103 896 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +18%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-kungsholmstorg-stockholms-kommun-kungsklippan-20-674795">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Chapmansgatan 2</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             83 m²
#
#             3,5 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 878 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 6 880 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 12 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           82 892 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +4%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-3,5rum-kungsholmen-stockholms-kommun-chapmansgatan-2-674415">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/2183" onclick=";hnt.tl('/tally/maklarfirma/2183/sold_listing_sold_clicks');">Bjurfors Vasastan Kungsholmen</a>
# </div>
# </div>

# %%
len(listings)
# Out:
# 50

# %%
#Stadsdel

# %%
for entry in listings:
    print entry.findAll('div', {'class':'sold-property-listing__location'})
    print ' '
    print type(entry)
# Out:
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Gyllenborgsgatan 18</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Thorildsplan,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Industrigatan 14</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Industrigatan 5, 4tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Alstr\xf6mergatan 21, 2 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Wivalliusgatan 17, 2 tr (5 tr)</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen - Marieberg,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Sankt G\xf6ransgatan 72, 4/4tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen - Fridhemsplan,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Ernst Ahlgrens v\xe4g 5, 2tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen Fredh\xe4ll,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Patentgatan 9</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Lilla Essingen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Kronobergsgatan 18, 3 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Vitalisv\xe4gen 11</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen/Fredh\xe4ll,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Kungsholmstorg 11, 5 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Kungsklippan 22</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Hj\xe4rnegatan 9, 1,5 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Svarvargatan 10, 2 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen Fridhemsplan,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Creutzgatan 5, V\xe5n 4/4</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Vitalisv\xe4gen 3, v\xe5n 3</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Fredh\xe4ll,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Ulriksborgsgatan 9, 8 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">P\xe4r Lagerkvists gata 30, 7 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen Hornsbergs Strand,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Fr\xf6dingsv\xe4gen 6, 1 1/2 TR</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen - Fredh\xe4ll,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="13" viewbox="0 0 13 13" width="13" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Radhus</span></desc><title>icon_radhus_inactive</title><path d="M6.5 3.25L4.062 0 0 5.417v6.5C0 12.515.485 13 1.083 13H3.25V9.208h1.625V13h3.25V9.208H9.75V13h2.167c.598 0 1.083-.485 1.083-1.083v-6.5L8.937 0 6.5 3.25z" fill="#45A366" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Grubbensringen 6, 3tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4tt\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Industrigatan 16</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Fridhemsgatan 62, 3 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Sankt G\xf6ransgatan 135, 2tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Birger Sj\xf6bergs v\xe4g 3, 3 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen Fredh\xe4ll,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Stagneliusv\xe4gen 42</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">R\xe5lambsv\xe4gen 8 A, 5 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Franz\xe9ngatan 52, 8 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen-Hornsbergs Strand,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Kristinebergs Strand 33, 4 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen - Kristinebergs Strand,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Grubbens Gata 1, 1,5 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Pontonj\xe4rgatan 47, 1,5 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Kungsgatan 86, 2 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Pipersgatan 9, 1 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen - Nedre Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Fridhemsgatan 33 A</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Fridhemsgatan 29 D, 2 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Kungsholms Strand 169, 5 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Wargentinsgatan 5D</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Kungsgatan 80A</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Sankt Eriksgatan 55 A, 4 tr i g\xe5rdshuset</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Lindhagensterrassen 19, 3 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen/Lindhagensterassen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Adlerbethsgatan 15, 1tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Fredh\xe4ll,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Celsiusgatan 8, 4 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Gyllenborgsgatan 22</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Kellgrensgatan 10, 10 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen/Stadshagen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Kungsholms Strand 107</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Kaplansbacken 5, 7 tr</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Chapmansgatan 5</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Ola Hanssonsgatan 5</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kristineberg,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Pipersgatan 26</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Kungsklippan 20</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen/Kungsholmstorg,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>
# [<div class="sold-property-listing__location">\n<h2 class="sold-property-listing__heading">\n<span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsr\xe4tt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>\n</span>\n<span class="item-result-meta-attribute-is-bold item-link">Chapmansgatan 2</span>\n</h2>\n<div>\n<span class="hide-element">\n        Bostadsr\xe4ttsl\xe4genhet\n      </span>\n<span class="item-link">\n          Kungsholmen,\n</span>      Stockholm\n    </div>\n</div>]
#
# <class 'bs4.element.Tag'>

# %%
for entry in listings:
    sub = entry.findAll('div', {'class':'sold-property-listing__location'})
    for i in sub:
        print i.findAll('span', {'class':'item-link'})
        print ' '
# Out:
# [<span class="item-result-meta-attribute-is-bold item-link">Gyllenborgsgatan 18</span>, <span class="item-link">\n          Thorildsplan,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Industrigatan 14</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Industrigatan 5, 4tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Alstr\xf6mergatan 21, 2 tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Wivalliusgatan 17, 2 tr (5 tr)</span>, <span class="item-link">\n          Kungsholmen - Marieberg,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Sankt G\xf6ransgatan 72, 4/4tr</span>, <span class="item-link">\n          Kungsholmen - Fridhemsplan,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Ernst Ahlgrens v\xe4g 5, 2tr</span>, <span class="item-link">\n          Kungsholmen Fredh\xe4ll,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Patentgatan 9</span>, <span class="item-link">\n          Lilla Essingen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Kronobergsgatan 18, 3 tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Vitalisv\xe4gen 11</span>, <span class="item-link">\n          Kungsholmen/Fredh\xe4ll,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Kungsholmstorg 11, 5 tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Kungsklippan 22</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Hj\xe4rnegatan 9, 1,5 tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Svarvargatan 10, 2 tr</span>, <span class="item-link">\n          Kungsholmen Fridhemsplan,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Creutzgatan 5, V\xe5n 4/4</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Vitalisv\xe4gen 3, v\xe5n 3</span>, <span class="item-link">\n          Fredh\xe4ll,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Ulriksborgsgatan 9, 8 tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">P\xe4r Lagerkvists gata 30, 7 tr</span>, <span class="item-link">\n          Kungsholmen Hornsbergs Strand,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Fr\xf6dingsv\xe4gen 6, 1 1/2 TR</span>, <span class="item-link">\n          Kungsholmen - Fredh\xe4ll,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Grubbensringen 6, 3tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Industrigatan 16</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Fridhemsgatan 62, 3 tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Sankt G\xf6ransgatan 135, 2tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Birger Sj\xf6bergs v\xe4g 3, 3 tr</span>, <span class="item-link">\n          Kungsholmen Fredh\xe4ll,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Stagneliusv\xe4gen 42</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">R\xe5lambsv\xe4gen 8 A, 5 tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Franz\xe9ngatan 52, 8 tr</span>, <span class="item-link">\n          Kungsholmen-Hornsbergs Strand,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Kristinebergs Strand 33, 4 tr</span>, <span class="item-link">\n          Kungsholmen - Kristinebergs Strand,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Grubbens Gata 1, 1,5 tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Pontonj\xe4rgatan 47, 1,5 tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Kungsgatan 86, 2 tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Pipersgatan 9, 1 tr</span>, <span class="item-link">\n          Kungsholmen - Nedre Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Fridhemsgatan 33 A</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Fridhemsgatan 29 D, 2 tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Kungsholms Strand 169, 5 tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Wargentinsgatan 5D</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Kungsgatan 80A</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Sankt Eriksgatan 55 A, 4 tr i g\xe5rdshuset</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Lindhagensterrassen 19, 3 tr</span>, <span class="item-link">\n          Kungsholmen/Lindhagensterassen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Adlerbethsgatan 15, 1tr</span>, <span class="item-link">\n          Fredh\xe4ll,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Celsiusgatan 8, 4 tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Gyllenborgsgatan 22</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Kellgrensgatan 10, 10 tr</span>, <span class="item-link">\n          Kungsholmen/Stadshagen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Kungsholms Strand 107</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Kaplansbacken 5, 7 tr</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Chapmansgatan 5</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Ola Hanssonsgatan 5</span>, <span class="item-link">\n          Kristineberg,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Pipersgatan 26</span>, <span class="item-link">\n          Kungsholmen,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Kungsklippan 20</span>, <span class="item-link">\n          Kungsholmen/Kungsholmstorg,\n</span>]
#
# [<span class="item-result-meta-attribute-is-bold item-link">Chapmansgatan 2</span>, <span class="item-link">\n          Kungsholmen,\n</span>]

# %%
locations = []

for entry in listings:
    sub = entry.findAll('div', {'class':'sold-property-listing__location'})
    for i in sub:
        output = i.findAll('span', {'class':'item-link'})
        locations.append(output)

# %%
for entry in listings:
    locations = entry.findAll('div', {'class':'sold-property-listing__location'})
    for entry in locations:
        str_entry = str(entry)
        id_location = str_entry.find('<span class="item-link"') + 1
        if id_location>0:
            start_location = id_location + 25
            remaining = str_entry[start_location:]
            remaining = remaining.lstrip(' ')
            end_location = str(remaining).find(',')
            remaining = remaining[:end_location]
        else:
            remaining = 'Saknas'
        print remaining
# Out:
# Thorildsplan
# Kungsholmen
# Kungsholmen
# Kungsholmen
# Kungsholmen - Marieberg
# Kungsholmen - Fridhemsplan
# Kungsholmen Fredhäll
# Lilla Essingen
# Kungsholmen
# Kungsholmen/Fredhäll
# Kungsholmen
# Kungsholmen
# Kungsholmen
# Kungsholmen Fridhemsplan
# Kungsholmen
# Fredhäll
# Kungsholmen
# Kungsholmen Hornsbergs Strand
# Kungsholmen - Fredhäll
# Kungsholmen
# Kungsholmen
# Kungsholmen
# Kungsholmen
# Kungsholmen Fredhäll
# Saknas
# Kungsholmen
# Kungsholmen-Hornsbergs Strand
# Kungsholmen - Kristinebergs Strand
# Kungsholmen
# Kungsholmen
# Kungsholmen
# Kungsholmen - Nedre Kungsholmen
# Kungsholmen
# Kungsholmen
# Kungsholmen
# Kungsholmen
# Kungsholmen
# Kungsholmen
# Kungsholmen/Lindhagensterassen
# Fredhäll
# Kungsholmen
# Kungsholmen
# Kungsholmen/Stadshagen
# Kungsholmen
# Kungsholmen
# Kungsholmen
# Kristineberg
# Kungsholmen
# Kungsholmen/Kungsholmstorg
# Kungsholmen

# %%
#Address

for entry in listings:
    locations = entry.findAll('div', {'class':'sold-property-listing__location'})
    for entry in locations:
        str_entry = str(entry)
        start_location = str_entry.find('item-link') + 11
        remaining = str_entry[start_location:]
        end_location = remaining.find('<')
        remaining = remaining[:end_location]
        print remaining
        print ' '
# Out:
# Gyllenborgsgatan 18
#
# Industrigatan 14
#
# Industrigatan 5, 4tr
#
# Alströmergatan 21, 2 tr
#
# Wivalliusgatan 17, 2 tr (5 tr)
#
# Sankt Göransgatan 72, 4/4tr
#
# Ernst Ahlgrens väg 5, 2tr
#
# Patentgatan 9
#
# Kronobergsgatan 18, 3 tr
#
# Vitalisvägen 11
#
# Kungsholmstorg 11, 5 tr
#
# Kungsklippan 22
#
# Hjärnegatan 9, 1,5 tr
#
# Svarvargatan 10, 2 tr
#
# Creutzgatan 5, Vån 4/4
#
# Vitalisvägen 3, vån 3
#
# Ulriksborgsgatan 9, 8 tr
#
# Pär Lagerkvists gata 30, 7 tr
#
# Frödingsvägen 6, 1 1/2 TR
#
# Grubbensringen 6, 3tr
#
# Industrigatan 16
#
# Fridhemsgatan 62, 3 tr
#
# Sankt Göransgatan 135, 2tr
#
# Birger Sjöbergs väg 3, 3 tr
#
# Stagneliusvägen 42
#
# Rålambsvägen 8 A, 5 tr
#
# Franzéngatan 52, 8 tr
#
# Kristinebergs Strand 33, 4 tr
#
# Grubbens Gata 1, 1,5 tr
#
# Pontonjärgatan 47, 1,5 tr
#
# Kungsgatan 86, 2 tr
#
# Pipersgatan 9, 1 tr
#
# Fridhemsgatan 33 A
#
# Fridhemsgatan 29 D, 2 tr
#
# Kungsholms Strand 169, 5 tr
#
# Wargentinsgatan 5D
#
# Kungsgatan 80A
#
# Sankt Eriksgatan 55 A, 4 tr i gårdshuset
#
# Lindhagensterrassen 19, 3 tr
#
# Adlerbethsgatan 15, 1tr
#
# Celsiusgatan 8, 4 tr
#
# Gyllenborgsgatan 22
#
# Kellgrensgatan 10, 10 tr
#
# Kungsholms Strand 107
#
# Kaplansbacken 5, 7 tr
#
# Chapmansgatan 5
#
# Ola Hanssonsgatan 5
#
# Pipersgatan 26
#
# Kungsklippan 20
#
# Chapmansgatan 2

# %%
#Maklare

# %%
for entry in listings:
    print entry
    print ' '
# Out:
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Gyllenborgsgatan 18</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Thorildsplan,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             34,5 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 850 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 100 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           89 855 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +15%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-thorildsplan-stockholms-kommun-gyllenborgsgatan-18-677968">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/304951" onclick=";hnt.tl('/tally/maklarfirma/304951/sold_listing_sold_clicks');">Erik Olsson Fastighetsförmedling</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Industrigatan 14</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             34 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 281 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 130 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           92 059 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +8%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-stockholms-kommun-industrigatan-14-677734">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/36331" onclick=";hnt.tl('/tally/maklarfirma/36331/sold_listing_sold_clicks');">ERA Bostad Sthlm</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Industrigatan 5, 4tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             37 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 339 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 750 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           101 351 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +17%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stockholms-kommun-industrigatan-5,-4tr-678607">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/22747" onclick=";hnt.tl('/tally/maklarfirma/22747/sold_listing_sold_clicks');">Mäklarhuset Stockholm Innerstan</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Alströmergatan 21, 2 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             95,5 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 870 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 7 700 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           80 628 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-down fa-lg price-icon--down"></i> -1%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-4rum-kungsholmen-stockholms-kommun-alstromergatan-21,-2-tr-677998">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Wivalliusgatan 17, 2 tr (5 tr)</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen - Marieberg,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             42 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 444 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 800 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           90 476 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +10%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-marieberg-stockholms-kommun-wivalliusgatan-17,-2-tr-5-tr-677931">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Sankt Göransgatan 72, 4/4tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen - Fridhemsplan,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             26 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             564 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 330 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           128 077 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-fridhemsplan-stockholms-kommun-sankt-goransgatan-72,-4-4tr-677763">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/29787" onclick=";hnt.tl('/tally/maklarfirma/29787/sold_listing_sold_clicks');">BOSTHLM Fastighetsmäklare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Ernst Ahlgrens väg 5, 2tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen Fredhäll,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             44 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 373 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 450 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           78 409 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +15%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-fredhall-stockholms-kommun-ernst-ahlgrens-vag-5,-2tr-677936">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/709471" onclick=";hnt.tl('/tally/maklarfirma/709471/sold_listing_sold_clicks');">MOHV Kungsholmen AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Patentgatan 9</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Lilla Essingen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             62 m²
#
#             2,5 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 021 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 4 680 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 19 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           75 484 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +5%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2,5rum-lilla-essingen-stockholms-kommun-patentgatan-9-678003">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kronobergsgatan 18, 3 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             90 m²
#
#             3,5 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 969 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 7 350 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           81 667 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-down fa-lg price-icon--down"></i> -4%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-3,5rum-kungsholmen-stockholms-kommun-kronobergsgatan-18,-3-tr-678409">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Vitalisvägen 11</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen/Fredhäll,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             38 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 115 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 2 975 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           78 289 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +21%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-fredhall-stockholms-kommun-vitalisvagen-11-678241">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kungsholmstorg 11, 5 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             106 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 872 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 11 850 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           111 792 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +22%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-4rum-kungsholmen-stockholms-kommun-kungsholmstorg-11,-5-tr-677272">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kungsklippan 22</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             37,5 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 749 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 600 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           96 000 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +22%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stockholms-kommun-kungsklippan-22-677290">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/427251" onclick=";hnt.tl('/tally/maklarfirma/427251/sold_listing_sold_clicks');">Erik Olsson Fastighetsförmedling</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Hjärnegatan 9, 1,5 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             76 m²
#
#             3 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 452 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 6 675 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           87 829 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +6%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-3rum-kungsholmen-stockholms-kommun-hjarnegatan-9,-1,5-tr-677283">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/929" onclick=";hnt.tl('/tally/maklarfirma/929/sold_listing_sold_clicks');">Karlsson &amp; Uddare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Svarvargatan 10, 2 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen Fridhemsplan,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             24 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 285 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 2 600 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           108 333 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +37%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-fridhemsplan-stockholms-kommun-svarvargatan-10,-2-tr-677313">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/424" onclick=";hnt.tl('/tally/maklarfirma/424/sold_listing_sold_clicks');">HusmanHagberg Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Creutzgatan 5, Vån 4/4</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             37 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 994 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 250 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           87 838 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +16%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-stockholms-kommun-creutzgatan-5,-van-4-4-677415">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/29607" onclick=";hnt.tl('/tally/maklarfirma/29607/sold_listing_sold_clicks');">Länsförsäkringar Fastighetsförmedling Stockholm - Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Vitalisvägen 3, vån 3</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Fredhäll,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             42 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 203 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 400 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           80 952 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +15%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-fredhall-stockholms-kommun-vitalisvagen-3,-van-3-677758">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/9045" onclick=";hnt.tl('/tally/maklarfirma/9045/sold_listing_sold_clicks');">Notar</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Ulriksborgsgatan 9, 8 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             40 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 582 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 500 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           87 500 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +18%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-stockholms-kommun-ulriksborgsgatan-9,-8-tr-677778">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/1927" onclick=";hnt.tl('/tally/maklarfirma/1927/sold_listing_sold_clicks');">Bostadsrättsspecialisten</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Pär Lagerkvists gata 30, 7 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen Hornsbergs Strand,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             74 m²
#
#             3 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 428 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 6 150 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           83 108 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +4%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-3rum-kungsholmen-hornsbergs-strand-stockholms-kommun-par-lagerkvists-gata-30,-7-tr-677288">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/424" onclick=";hnt.tl('/tally/maklarfirma/424/sold_listing_sold_clicks');">HusmanHagberg Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Frödingsvägen 6, 1 1/2 TR</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen - Fredhäll,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             38 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 787 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 350 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           88 158 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-fredhall-stockholms-kommun-frodingsvagen-6,-1-1-2-tr-677104">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/29787" onclick=";hnt.tl('/tally/maklarfirma/29787/sold_listing_sold_clicks');">BOSTHLM Fastighetsmäklare AB</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="13" viewbox="0 0 13 13" width="13" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Radhus</span></desc><title>icon_radhus_inactive</title><path d="M6.5 3.25L4.062 0 0 5.417v6.5C0 12.515.485 13 1.083 13H3.25V9.208h1.625V13h3.25V9.208H9.75V13h2.167c.598 0 1.083-.485 1.083-1.083v-6.5L8.937 0 6.5 3.25z" fill="#45A366" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Grubbensringen 6, 3tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrätt
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             99 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             6 483 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 7 700 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/radhus-4rum-kungsholmen-stockholms-kommun-grubbensringen-6,-3tr-677641">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/29607" onclick=";hnt.tl('/tally/maklarfirma/29607/sold_listing_sold_clicks');">Länsförsäkringar Fastighetsförmedling Stockholm - Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Industrigatan 16</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             49 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 494 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 4 150 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           84 694 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +4%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stockholms-kommun-industrigatan-16-677130">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/701671" onclick=";hnt.tl('/tally/maklarfirma/701671/sold_listing_sold_clicks');">Svensk Fastighetsförmedling Sthlm Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Fridhemsgatan 62, 3 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             47 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 898 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 5 260 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           111 915 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +35%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stockholms-kommun-fridhemsgatan-62,-3-tr-677150">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/701671" onclick=";hnt.tl('/tally/maklarfirma/701671/sold_listing_sold_clicks');">Svensk Fastighetsförmedling Sthlm Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Sankt Göransgatan 135, 2tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             113,5 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             6 529 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 8 400 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 18 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           74 009 kr/m²
#         </div>
# </div>
# </div>
# ...
# <span class="item-link">
#           Kungsholmen/Stadshagen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             53,5 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 473 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 4 550 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 15 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           85 047 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +14%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-stadshagen-stockholms-kommun-kellgrensgatan-10,-10-tr-675530">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kungsholms Strand 107</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             113 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             6 399 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 9 900 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 15 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           87 611 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-4rum-kungsholmen-stockholms-kommun-kungsholms-strand-107-675388">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/8985" onclick=";hnt.tl('/tally/maklarfirma/8985/sold_listing_sold_clicks');">Notar</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kaplansbacken 5, 7 tr</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             35 m²
#
#             1 rum
#         </div>
# <div class="sold-property-listing__fee">
#             1 861 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 850 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 14 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           110 000 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +29%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-1rum-kungsholmen-stockholms-kommun-kaplansbacken-5,-7-tr-675051">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Chapmansgatan 5</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             87 m²
#
#             2,5 rum
#         </div>
# <div class="sold-property-listing__fee">
#             3 776 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 8 700 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 13 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           100 000 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2,5rum-kungsholmen-stockholms-kommun-chapmansgatan-5-674666">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/2051" onclick=";hnt.tl('/tally/maklarfirma/2051/sold_listing_sold_clicks');">Living Fastighetsmäkleri</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Ola Hanssonsgatan 5</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kristineberg,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             37 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 437 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 3 425 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 13 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           92 568 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +37%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kristineberg-stockholms-kommun-ola-hanssonsgatan-5-674613">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/427251" onclick=";hnt.tl('/tally/maklarfirma/427251/sold_listing_sold_clicks');">Erik Olsson Fastighetsförmedling</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Pipersgatan 26</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             120 m²
#
#             4 rum
#         </div>
# <div class="sold-property-listing__fee">
#             4 935 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 10 600 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 13 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           88 333 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +12%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-4rum-kungsholmen-stockholms-kommun-pipersgatan-26-674606">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/303735" onclick=";hnt.tl('/tally/maklarfirma/303735/sold_listing_sold_clicks');">Erik Olsson Fastighetsförmedling</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Kungsklippan 20</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen/Kungsholmstorg,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             38,5 m²
#
#             2 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 807 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 4 000 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 12 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           103 896 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +18%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-2rum-kungsholmen-kungsholmstorg-stockholms-kommun-kungsklippan-20-674795">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/41" onclick=";hnt.tl('/tally/maklarfirma/41/sold_listing_sold_clicks');">Fastighetsbyrån Kungsholmen</a>
# </div>
# </div>
#
# <div class="sold-property-listing">
# <div class="sold-property-listing__location">
# <h2 class="sold-property-listing__heading">
# <span class="property-icon property-icon--result"><svg height="16" viewbox="0 0 14 16" width="14" xmlns="http://www.w3.org/2000/svg"><desc><span class="svg-icon__fallback-text">Bostadsrätt</span></desc><title>icon_brf_inactive</title><path d="M0 1.333v13.334C0 15.403.597 16 1.333 16h4v-5.333H8V16h4c.737 0 1.333-.597 1.333-1.333V1.333C13.333.597 12.737 0 12 0H1.333C.597 0 0 .597 0 1.333" fill="#C1569D" fill-rule="evenodd"></path></svg>
# </span>
# <span class="item-result-meta-attribute-is-bold item-link">Chapmansgatan 2</span>
# </h2>
# <div>
# <span class="hide-element">
#         Bostadsrättslägenhet
#       </span>
# <span class="item-link">
#           Kungsholmen,
# </span>      Stockholm
#     </div>
# </div>
# <div class="sold-property-listing__size">
# <div class="clear-children">
# <div class="sold-property-listing__subheading sold-property-listing--left">
#             83 m²
#
#             3,5 rum
#         </div>
# <div class="sold-property-listing__fee">
#             2 878 kr/mån
#           </div>
# </div>
# </div>
# <div class="sold-property-listing__price">
# <div class="clear-children">
# <span class="sold-property-listing__subheading sold-property-listing--left">
#         Slutpris 6 880 000 kr
# </span> </div>
# <div class="clear-children">
# <div class="sold-property-listing__sold-date sold-property-listing--left">
#           Såld 12 maj 2017
#         </div>
# <div class="sold-property-listing__price-per-m2 sold-property-listing--left">
#           82 892 kr/m²
#         </div>
# </div>
# </div>
# <div class="sold-property-listing__price-change">
# <i class="fa fa-arrow-circle-o-up fa-lg price-icon--up"></i> +4%
#     </div>
# <a class="item-link-container" data-target-blank="true" href="https://www.hemnet.se/salda/bostadsratt-3,5rum-kungsholmen-stockholms-kommun-chapmansgatan-2-674415">
#
# </a>
# <div class="sold-property-listing__broker">
# <a href="/maklare/salda/2183" onclick=";hnt.tl('/tally/maklarfirma/2183/sold_listing_sold_clicks');">Bjurfors Vasastan Kungsholmen</a>
# </div>
# </div>

# %%
brokers_list = []

for entry in listings:
    brokers = entry.findAll('div', {'class':'sold-property-listing__broker'})
    for entry in brokers:
        str_entry = str(entry)
        id_location = str_entry.find('sold_clicks')
        if id_location>0:
            remaining = str_entry[id_location:]
            start_location = remaining.find('>') + 1
            end_location = remaining.find('<')
            remaining = remaining[start_location:end_location]
        else:
            remaining = 'Saknas'
        brokers_list.append(remaining)
